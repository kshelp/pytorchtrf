# %%
import torch
from torch import onnx
from torchvision import models


model = models.vgg16(num_classes=2)
model.load_state_dict(torch.load("../models/VGG16.pt"))
model.eval()

dummy_input = torch.randn(1, 3, 224, 224)
onnx.export(model=model, args=dummy_input, f="../models/VGG16.onnx")
# Out:
# W0226 11:36:53.368000 65118 /Users/iwon-yong/.pyenv/versions/3.10.14/envs/venv310/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0226 11:36:53.392000 65118 /Users/iwon-yong/.pyenv/versions/3.10.14/envs/venv310/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0226 11:36:53.395000 65118 /Users/iwon-yong/.pyenv/versions/3.10.14/envs/venv310/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0226 11:36:53.397000 65118 /Users/iwon-yong/.pyenv/versions/3.10.14/envs/venv310/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `VGG([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `VGG([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /Users/iwon-yong/.pyenv/versions/3.10.14/lib/python3.10/copyreg.py:101: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 20},
#             producer_name='pytorch',
#             producer_version='2.10.0',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"x"<FLOAT,[1,3,224,224]>
#             ),
#             outputs=(
#                 %"linear_2"<FLOAT,[1,2]>
#             ),
#             initializers=(
#                 %"features.0.weight"<FLOAT,[64,3,3,3]>{TorchTensor(...)},
#                 %"features.0.bias"<FLOAT,[64]>{TorchTensor(...)},
#                 %"features.2.weight"<FLOAT,[64,64,3,3]>{TorchTensor(...)},
#                 %"features.2.bias"<FLOAT,[64]>{TorchTensor(...)},
#                 %"features.5.weight"<FLOAT,[128,64,3,3]>{TorchTensor(...)},
#                 %"features.5.bias"<FLOAT,[128]>{TorchTensor(...)},
#                 %"features.7.weight"<FLOAT,[128,128,3,3]>{TorchTensor(...)},
#                 %"features.7.bias"<FLOAT,[128]>{TorchTensor(...)},
#                 %"features.10.weight"<FLOAT,[256,128,3,3]>{TorchTensor(...)},
#                 %"features.10.bias"<FLOAT,[256]>{TorchTensor(...)},
#                 %"features.12.weight"<FLOAT,[256,256,3,3]>{TorchTensor(...)},
#                 %"features.12.bias"<FLOAT,[256]>{TorchTensor(...)},
#                 %"features.14.weight"<FLOAT,[256,256,3,3]>{TorchTensor(...)},
#                 %"features.14.bias"<FLOAT,[256]>{TorchTensor(...)},
#                 %"features.17.weight"<FLOAT,[512,256,3,3]>{TorchTensor(...)},
#                 %"features.17.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.19.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.19.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.21.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.21.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.24.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.24.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.26.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.26.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.28.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.28.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"classifier.0.weight"<FLOAT,[4096,25088]>{TorchTensor(...)},
#                 %"classifier.0.bias"<FLOAT,[4096]>{TorchTensor(...)},
#                 %"classifier.3.weight"<FLOAT,[4096,4096]>{TorchTensor(...)},
#                 %"classifier.3.bias"<FLOAT,[4096]>{TorchTensor(...)},
#                 %"classifier.6.weight"<FLOAT,[2,4096]>{TorchTensor(...)},
#                 %"classifier.6.bias"<FLOAT,[2]>{TorchTensor<FLOAT,[2]>(Parameter containing: tensor([0.0088, 0.0028], requires_grad=True), name='classifier.6.bias')},
#                 %"val_8"<INT64,[2]>{Tensor<INT64,[2]>(array([    1, 25088]), name='val_8')}
#             ),
#         ) {
#              0 |  # node_conv2d
#                   %"conv2d"<FLOAT,[1,64,224,224]> ⬅️ ::Conv(%"x", %"features.0.weight"{...}, %"features.0.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#              1 |  # node_relu
#                   %"relu"<FLOAT,[1,64,224,224]> ⬅️ ::Relu(%"conv2d")
#              2 |  # node_conv2d_1
#                   %"conv2d_1"<FLOAT,[1,64,224,224]> ⬅️ ::Conv(%"relu", %"features.2.weight"{...}, %"features.2.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#              3 |  # node_relu_1
#                   %"relu_1"<FLOAT,[1,64,224,224]> ⬅️ ::Relu(%"conv2d_1")
#              4 |  # node_max_pool2d
#                   %"max_pool2d"<FLOAT,[1,64,112,112]> ⬅️ ::MaxPool(%"relu_1") {storage_order=0, ceil_mode=0, pads=(0, 0, 0, 0), kernel_shape=(2, 2), strides=(2, 2), dilations=(1, 1), auto_pad='NOTSET'}
#              5 |  # node_conv2d_2
#                   %"conv2d_2"<FLOAT,[1,128,112,112]> ⬅️ ::Conv(%"max_pool2d", %"features.5.weight"{...}, %"features.5.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#              6 |  # node_relu_2
#                   %"relu_2"<FLOAT,[1,128,112,112]> ⬅️ ::Relu(%"conv2d_2")
#              7 |  # node_conv2d_3
#                   %"conv2d_3"<FLOAT,[1,128,112,112]> ⬅️ ::Conv(%"relu_2", %"features.7.weight"{...}, %"features.7.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#              8 |  # node_relu_3
#                   %"relu_3"<FLOAT,[1,128,112,112]> ⬅️ ::Relu(%"conv2d_3")
#              9 |  # node_max_pool2d_1
#                   %"max_pool2d_1"<FLOAT,[1,128,56,56]> ⬅️ ::MaxPool(%"relu_3") {storage_order=0, ceil_mode=0, pads=(0, 0, 0, 0), kernel_shape=(2, 2), strides=(2, 2), dilations=(1, 1), auto_pad='NOTSET'}
#             10 |  # node_conv2d_4
#                   %"conv2d_4"<FLOAT,[1,256,56,56]> ⬅️ ::Conv(%"max_pool2d_1", %"features.10.weight"{...}, %"features.10.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             11 |  # node_relu_4
#                   %"relu_4"<FLOAT,[1,256,56,56]> ⬅️ ::Relu(%"conv2d_4")
#             12 |  # node_conv2d_5
#                   %"conv2d_5"<FLOAT,[1,256,56,56]> ⬅️ ::Conv(%"relu_4", %"features.12.weight"{...}, %"features.12.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             13 |  # node_relu_5
#                   %"relu_5"<FLOAT,[1,256,56,56]> ⬅️ ::Relu(%"conv2d_5")
#             14 |  # node_conv2d_6
#                   %"conv2d_6"<FLOAT,[1,256,56,56]> ⬅️ ::Conv(%"relu_5", %"features.14.weight"{...}, %"features.14.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             15 |  # node_relu_6
#                   %"relu_6"<FLOAT,[1,256,56,56]> ⬅️ ::Relu(%"conv2d_6")
#             16 |  # node_max_pool2d_2
#                   %"max_pool2d_2"<FLOAT,[1,256,28,28]> ⬅️ ::MaxPool(%"relu_6") {storage_order=0, ceil_mode=0, pads=(0, 0, 0, 0), kernel_shape=(2, 2), strides=(2, 2), dilations=(1, 1), auto_pad='NOTSET'}
#             17 |  # node_conv2d_7
#                   %"conv2d_7"<FLOAT,[1,512,28,28]> ⬅️ ::Conv(%"max_pool2d_2", %"features.17.weight"{...}, %"features.17.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             18 |  # node_relu_7
#                   %"relu_7"<FLOAT,[1,512,28,28]> ⬅️ ::Relu(%"conv2d_7")
#             19 |  # node_conv2d_8
#                   %"conv2d_8"<FLOAT,[1,512,28,28]> ⬅️ ::Conv(%"relu_7", %"features.19.weight"{...}, %"features.19.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             20 |  # node_relu_8
#                   %"relu_8"<FLOAT,[1,512,28,28]> ⬅️ ::Relu(%"conv2d_8")
#             21 |  # node_conv2d_9
#                   %"conv2d_9"<FLOAT,[1,512,28,28]> ⬅️ ::Conv(%"relu_8", %"features.21.weight"{...}, %"features.21.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             22 |  # node_relu_9
#                   %"relu_9"<FLOAT,[1,512,28,28]> ⬅️ ::Relu(%"conv2d_9")
#             23 |  # node_max_pool2d_3
#                   %"max_pool2d_3"<FLOAT,[1,512,14,14]> ⬅️ ::MaxPool(%"relu_9") {storage_order=0, ceil_mode=0, pads=(0, 0, 0, 0), kernel_shape=(2, 2), strides=(2, 2), dilations=(1, 1), auto_pad='NOTSET'}
#             24 |  # node_conv2d_10
#                   %"conv2d_10"<FLOAT,[1,512,14,14]> ⬅️ ::Conv(%"max_pool2d_3", %"features.24.weight"{...}, %"features.24.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             25 |  # node_relu_10
#                   %"relu_10"<FLOAT,[1,512,14,14]> ⬅️ ::Relu(%"conv2d_10")
#             26 |  # node_conv2d_11
#                   %"conv2d_11"<FLOAT,[1,512,14,14]> ⬅️ ::Conv(%"relu_10", %"features.26.weight"{...}, %"features.26.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             27 |  # node_relu_11
#                   %"relu_11"<FLOAT,[1,512,14,14]> ⬅️ ::Relu(%"conv2d_11")
#             28 |  # node_conv2d_12
#                   %"conv2d_12"<FLOAT,[1,512,14,14]> ⬅️ ::Conv(%"relu_11", %"features.28.weight"{...}, %"features.28.bias"{...}) {group=1, pads=(1, 1, 1, 1), strides=(1, 1), auto_pad='NOTSET', dilations=(1, 1)}
#             29 |  # node_relu_12
#                   %"relu_12"<FLOAT,[1,512,14,14]> ⬅️ ::Relu(%"conv2d_12")
#             30 |  # node_max_pool2d_4
#                   %"max_pool2d_4"<FLOAT,[1,512,7,7]> ⬅️ ::MaxPool(%"relu_12") {storage_order=0, ceil_mode=0, pads=(0, 0, 0, 0), kernel_shape=(2, 2), strides=(2, 2), dilations=(1, 1), auto_pad='NOTSET'}
#             31 |  # node_avg_pool2d
#                   %"avg_pool2d"<FLOAT,[1,512,7,7]> ⬅️ ::AveragePool(%"max_pool2d_4") {count_include_pad=1, ceil_mode=0, pads=(0, 0, 0, 0), kernel_shape=(1, 1), strides=(1, 1), auto_pad='NOTSET'}
#             32 |  # node_view
#                   %"view"<FLOAT,[1,25088]> ⬅️ ::Reshape(%"avg_pool2d", %"val_8"{[1, 25088]}) {allowzero=1}
#             33 |  # node_linear
#                   %"linear"<FLOAT,[1,4096]> ⬅️ ::Gemm(%"view", %"classifier.0.weight"{...}, %"classifier.0.bias"{...}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             34 |  # node_relu_13
#                   %"relu_13"<FLOAT,[1,4096]> ⬅️ ::Relu(%"linear")
#             35 |  # node_linear_1
#                   %"linear_1"<FLOAT,[1,4096]> ⬅️ ::Gemm(%"relu_13", %"classifier.3.weight"{...}, %"classifier.3.bias"{...}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             36 |  # node_relu_14
#                   %"relu_14"<FLOAT,[1,4096]> ⬅️ ::Relu(%"linear_1")
#             37 |  # node_linear_2
#                   %"linear_2"<FLOAT,[1,2]> ⬅️ ::Gemm(%"relu_14", %"classifier.6.weight"{...}, %"classifier.6.bias"{[0.008847838267683983, 0.002761432435363531]}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             return %"linear_2"<FLOAT,[1,2]>
#         }
#
#
#     ,
#     exported_program=
#         ExportedProgram:
#             class GraphModule(torch.nn.Module):
#                 def forward(self, p_features_0_weight: "f32[64, 3, 3, 3]", p_features_0_bias: "f32[64]", p_features_2_weight: "f32[64, 64, 3, 3]", p_features_2_bias: "f32[64]", p_features_5_weight: "f32[128, 64, 3, 3]", p_features_5_bias: "f32[128]", p_features_7_weight: "f32[128, 128, 3, 3]", p_features_7_bias: "f32[128]", p_features_10_weight: "f32[256, 128, 3, 3]", p_features_10_bias: "f32[256]", p_features_12_weight: "f32[256, 256, 3, 3]", p_features_12_bias: "f32[256]", p_features_14_weight: "f32[256, 256, 3, 3]", p_features_14_bias: "f32[256]", p_features_17_weight: "f32[512, 256, 3, 3]", p_features_17_bias: "f32[512]", p_features_19_weight: "f32[512, 512, 3, 3]", p_features_19_bias: "f32[512]", p_features_21_weight: "f32[512, 512, 3, 3]", p_features_21_bias: "f32[512]", p_features_24_weight: "f32[512, 512, 3, 3]", p_features_24_bias: "f32[512]", p_features_26_weight: "f32[512, 512, 3, 3]", p_features_26_bias: "f32[512]", p_features_28_weight: "f32[512, 512, 3, 3]", p_features_28_bias: "f32[512]", p_classifier_0_weight: "f32[4096, 25088]", p_classifier_0_bias: "f32[4096]", p_classifier_3_weight: "f32[4096, 4096]", p_classifier_3_bias: "f32[4096]", p_classifier_6_weight: "f32[2, 4096]", p_classifier_6_bias: "f32[2]", x: "f32[1, 3, 224, 224]"):
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d: "f32[1, 64, 224, 224]" = torch.ops.aten.conv2d.default(x, p_features_0_weight, p_features_0_bias, [1, 1], [1, 1]);  x = p_features_0_weight = p_features_0_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu: "f32[1, 64, 224, 224]" = torch.ops.aten.relu.default(conv2d);  conv2d = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_1: "f32[1, 64, 224, 224]" = torch.ops.aten.conv2d.default(relu, p_features_2_weight, p_features_2_bias, [1, 1], [1, 1]);  relu = p_features_2_weight = p_features_2_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_1: "f32[1, 64, 224, 224]" = torch.ops.aten.relu.default(conv2d_1);  conv2d_1 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d: "f32[1, 64, 112, 112]" = torch.ops.aten.max_pool2d.default(relu_1, [2, 2], [2, 2]);  relu_1 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_2: "f32[1, 128, 112, 112]" = torch.ops.aten.conv2d.default(max_pool2d, p_features_5_weight, p_features_5_bias, [1, 1], [1, 1]);  max_pool2d = p_features_5_weight = p_features_5_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_2: "f32[1, 128, 112, 112]" = torch.ops.aten.relu.default(conv2d_2);  conv2d_2 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_3: "f32[1, 128, 112, 112]" = torch.ops.aten.conv2d.default(relu_2, p_features_7_weight, p_features_7_bias, [1, 1], [1, 1]);  relu_2 = p_features_7_weight = p_features_7_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_3: "f32[1, 128, 112, 112]" = torch.ops.aten.relu.default(conv2d_3);  conv2d_3 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_1: "f32[1, 128, 56, 56]" = torch.ops.aten.max_pool2d.default(relu_3, [2, 2], [2, 2]);  relu_3 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_4: "f32[1, 256, 56, 56]" = torch.ops.aten.conv2d.default(max_pool2d_1, p_features_10_weight, p_features_10_bias, [1, 1], [1, 1]);  max_pool2d_1 = p_features_10_weight = p_features_10_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_4: "f32[1, 256, 56, 56]" = torch.ops.aten.relu.default(conv2d_4);  conv2d_4 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_5: "f32[1, 256, 56, 56]" = torch.ops.aten.conv2d.default(relu_4, p_features_12_weight, p_features_12_bias, [1, 1], [1, 1]);  relu_4 = p_features_12_weight = p_features_12_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_5: "f32[1, 256, 56, 56]" = torch.ops.aten.relu.default(conv2d_5);  conv2d_5 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_6: "f32[1, 256, 56, 56]" = torch.ops.aten.conv2d.default(relu_5, p_features_14_weight, p_features_14_bias, [1, 1], [1, 1]);  relu_5 = p_features_14_weight = p_features_14_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_6: "f32[1, 256, 56, 56]" = torch.ops.aten.relu.default(conv2d_6);  conv2d_6 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_2: "f32[1, 256, 28, 28]" = torch.ops.aten.max_pool2d.default(relu_6, [2, 2], [2, 2]);  relu_6 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_7: "f32[1, 512, 28, 28]" = torch.ops.aten.conv2d.default(max_pool2d_2, p_features_17_weight, p_features_17_bias, [1, 1], [1, 1]);  max_pool2d_2 = p_features_17_weight = p_features_17_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_7: "f32[1, 512, 28, 28]" = torch.ops.aten.relu.default(conv2d_7);  conv2d_7 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_8: "f32[1, 512, 28, 28]" = torch.ops.aten.conv2d.default(relu_7, p_features_19_weight, p_features_19_bias, [1, 1], [1, 1]);  relu_7 = p_features_19_weight = p_features_19_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_8: "f32[1, 512, 28, 28]" = torch.ops.aten.relu.default(conv2d_8);  conv2d_8 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_9: "f32[1, 512, 28, 28]" = torch.ops.aten.conv2d.default(relu_8, p_features_21_weight, p_features_21_bias, [1, 1], [1, 1]);  relu_8 = p_features_21_weight = p_features_21_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_9: "f32[1, 512, 28, 28]" = torch.ops.aten.relu.default(conv2d_9);  conv2d_9 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_3: "f32[1, 512, 14, 14]" = torch.ops.aten.max_pool2d.default(relu_9, [2, 2], [2, 2]);  relu_9 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_10: "f32[1, 512, 14, 14]" = torch.ops.aten.conv2d.default(max_pool2d_3, p_features_24_weight, p_features_24_bias, [1, 1], [1, 1]);  max_pool2d_3 = p_features_24_weight = p_features_24_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_10: "f32[1, 512, 14, 14]" = torch.ops.aten.relu.default(conv2d_10);  conv2d_10 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_11: "f32[1, 512, 14, 14]" = torch.ops.aten.conv2d.default(relu_10, p_features_26_weight, p_features_26_bias, [1, 1], [1, 1]);  relu_10 = p_features_26_weight = p_features_26_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_11: "f32[1, 512, 14, 14]" = torch.ops.aten.relu.default(conv2d_11);  conv2d_11 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_12: "f32[1, 512, 14, 14]" = torch.ops.aten.conv2d.default(relu_11, p_features_28_weight, p_features_28_bias, [1, 1], [1, 1]);  relu_11 = p_features_28_weight = p_features_28_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_12: "f32[1, 512, 14, 14]" = torch.ops.aten.relu.default(conv2d_12);  conv2d_12 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_4: "f32[1, 512, 7, 7]" = torch.ops.aten.max_pool2d.default(relu_12, [2, 2], [2, 2]);  relu_12 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/pooling.py:1510 in forward, code: return F.adaptive_avg_pool2d(input, self.output_size)
#                     avg_pool2d: "f32[1, 512, 7, 7]" = torch.ops.aten.avg_pool2d.default(max_pool2d_4, [1, 1], [1, 1]);  max_pool2d_4 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torchvision/models/vgg.py:68 in forward, code: x = torch.flatten(x, 1)
#                     view: "f32[1, 25088]" = torch.ops.aten.view.default(avg_pool2d, [1, 25088]);  avg_pool2d = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear: "f32[1, 4096]" = torch.ops.aten.linear.default(view, p_classifier_0_weight, p_classifier_0_bias);  view = p_classifier_0_weight = p_classifier_0_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_13: "f32[1, 4096]" = torch.ops.aten.relu.default(linear);  linear = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/dropout.py:73 in forward, code: return F.dropout(input, self.p, self.training, self.inplace)
#                     clone: "f32[1, 4096]" = torch.ops.aten.clone.default(relu_13);  relu_13 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear_1: "f32[1, 4096]" = torch.ops.aten.linear.default(clone, p_classifier_3_weight, p_classifier_3_bias);  clone = p_classifier_3_weight = p_classifier_3_bias = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_14: "f32[1, 4096]" = torch.ops.aten.relu.default(linear_1);  linear_1 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/dropout.py:73 in forward, code: return F.dropout(input, self.p, self.training, self.inplace)
#                     clone_1: "f32[1, 4096]" = torch.ops.aten.clone.default(relu_14);  relu_14 = None
#
#                     # File: /Users/iwon-yong/.pyenv/versions/venv310/lib/python3.10/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear_2: "f32[1, 2]" = torch.ops.aten.linear.default(clone_1, p_classifier_6_weight, p_classifier_6_bias);  clone_1 = p_classifier_6_weight = p_classifier_6_bias = None
#                     return (linear_2,)
#
#         Graph signature:
#             # inputs
#             p_features_0_weight: PARAMETER target='features.0.weight'
#             p_features_0_bias: PARAMETER target='features.0.bias'
#             p_features_2_weight: PARAMETER target='features.2.weight'
#             p_features_2_bias: PARAMETER target='features.2.bias'
#             p_features_5_weight: PARAMETER target='features.5.weight'
#             p_features_5_bias: PARAMETER target='features.5.bias'
#             p_features_7_weight: PARAMETER target='features.7.weight'
#             p_features_7_bias: PARAMETER target='features.7.bias'
#             p_features_10_weight: PARAMETER target='features.10.weight'
#             p_features_10_bias: PARAMETER target='features.10.bias'
#             p_features_12_weight: PARAMETER target='features.12.weight'
#             p_features_12_bias: PARAMETER target='features.12.bias'
#             p_features_14_weight: PARAMETER target='features.14.weight'
#             p_features_14_bias: PARAMETER target='features.14.bias'
#             p_features_17_weight: PARAMETER target='features.17.weight'
#             p_features_17_bias: PARAMETER target='features.17.bias'
#             p_features_19_weight: PARAMETER target='features.19.weight'
#             p_features_19_bias: PARAMETER target='features.19.bias'
#             p_features_21_weight: PARAMETER target='features.21.weight'
#             p_features_21_bias: PARAMETER target='features.21.bias'
#             p_features_24_weight: PARAMETER target='features.24.weight'
#             p_features_24_bias: PARAMETER target='features.24.bias'
#             p_features_26_weight: PARAMETER target='features.26.weight'
#             p_features_26_bias: PARAMETER target='features.26.bias'
#             p_features_28_weight: PARAMETER target='features.28.weight'
#             p_features_28_bias: PARAMETER target='features.28.bias'
#             p_classifier_0_weight: PARAMETER target='classifier.0.weight'
#             p_classifier_0_bias: PARAMETER target='classifier.0.bias'
#             p_classifier_3_weight: PARAMETER target='classifier.3.weight'
#             p_classifier_3_bias: PARAMETER target='classifier.3.bias'
#             p_classifier_6_weight: PARAMETER target='classifier.6.weight'
#             p_classifier_6_bias: PARAMETER target='classifier.6.bias'
#             x: USER_INPUT
#
#             # outputs
#             linear_2: USER_OUTPUT
#
#         Range constraints: {}
#
# )
