# %%
from ultralytics import YOLO
import cv2

print("OpenCV version:", cv2.__version__)
model = YOLO("../models/numbers_best.pt")
 
cap = cv2.VideoCapture(0, cv2.CAP_DSHOW) # 0: 기본 카메라, 1: 외장 카메라
 
while cap.isOpened():
    ret, frame = cap.read() # True/False, ndarray/None
    if (not ret) or (cv2.waitKey(1)==27): # 27키코드는 ESC키
        print("프레임이 없거나 ESC키가 눌려짐")
        break
 
    # 영상처리 코드 삽입
    result = model.predict(frame, verbose=False, conf=0.25)
    for box in result[0].boxes:
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().flatten().astype(int)
        cv2.rectangle(frame, (x1,y1), (x2,y2), (0, 0, 255), 2)
        cv2.putText(frame, f'{result[0].names[int(box.cls)]} {float(box.conf):.4f}', (x1,y1), 
                    cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2) # 글꼴, 크기, 색, 두께
 
    cv2.imshow("Camera", frame)
 
cap.release()
cv2.destroyAllWindows()
# Out:
# OpenCV version: 4.11.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import cv2
#       4 print("OpenCV version:", cv2.__version__)
# ----> 5 model = YOLO("models/numbers_best.pt")
#       7 cap = cv2.VideoCapture(0, cv2.CAP_DSHOW) # 0: 기본 카메라, 1: 외장 카메라
#       9 while cap.isOpened():
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\ultralytics\models\yolo\model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
#      77     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78         from ultralytics import RTDETR
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\ultralytics\engine\model.py:144, in Model.__init__(self, model, task, verbose)
#     142     self._new(model, task=task, verbose=verbose)
#     143 else:
# --> 144     self._load(model, task=task)
#     146 # Delete super().training for accessing self.model.training
#     147 del self.training
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\ultralytics\engine\model.py:283, in Model._load(self, weights, task)
#     280 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo26 -> yolo26n.pt
#     282 if str(weights).rpartition(".")[-1] == "pt":
# --> 283     self.model, self.ckpt = load_checkpoint(weights)
#     284     self.task = self.model.task
#     285     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\ultralytics\nn\tasks.py:1515, in load_checkpoint(weight, device, inplace, fuse)
#    1502 def load_checkpoint(weight, device=None, inplace=True, fuse=False):
#    1503     """Load single model weights.
#    1504
#    1505     Args:
#    (...)   1513         (dict): Model checkpoint dictionary.
#    1514     """
# -> 1515     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1516     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1517     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\ultralytics\nn\tasks.py:1463, in torch_safe_load(weight, safe_only)
#    1461                 ckpt = torch_load(f, pickle_module=safe_pickle)
#    1462         else:
# -> 1463             ckpt = torch_load(file, map_location="cpu")
#    1465 except ModuleNotFoundError as e:  # e.name is missing module name
#    1466     if e.name == "models":
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\ultralytics\utils\patches.py:178, in torch_load(*args, **kwargs)
#     175 if TORCH_1_13 and "weights_only" not in kwargs:
#     176     kwargs["weights_only"] = False
# --> 178 return torch.load(*args, **kwargs)
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\torch\serialization.py:1425, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1422 if "encoding" not in pickle_load_args.keys():
#    1423     pickle_load_args["encoding"] = "utf-8"
# -> 1425 with _open_file_like(f, "rb") as opened_file:
#    1426     if _is_zipfile(opened_file):
#    1427         # The zipfile reader is going to advance the current file position.
#    1428         # If we want to actually tail call to torch.jit.load, we need to
#    1429         # reset back to the original position.
#    1430         orig_position = opened_file.tell()
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\torch\serialization.py:751, in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
#     750     if _is_path(name_or_buffer):
# --> 751         return _open_file(name_or_buffer, mode)
#     752     else:
#     753         if "w" in mode:
#
# File d:\dev\workspace\ai\pytorchtrf\.venv\Lib\site-packages\torch\serialization.py:732, in _open_file.__init__(self, name, mode)
#     731 def __init__(self, name, mode):
# --> 732     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models\\numbers_best.pt'
