# %%
import torch

tensor = torch.rand(1, 2)
print(tensor)
print(tensor.shape)
# Out:
# tensor([[0.8106, 0.7103]])
# torch.Size([1, 2])

# %%
tensor = tensor.reshape(2, 1)
print(tensor)
print(tensor.shape)
# Out:
# tensor([[0.8106],
#         [0.7103]])
# torch.Size([2, 1])
