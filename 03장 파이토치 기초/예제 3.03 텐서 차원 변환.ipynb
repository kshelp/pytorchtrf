# %%
import torch

tensor = torch.rand(1, 2)
print(tensor)
print(tensor.shape)

tensor = tensor.reshape(2, 1)
print(tensor)
print(tensor.shape)
# Out:
# tensor([[0.7628, 0.8137]])
# torch.Size([1, 2])
# tensor([[0.7628],
#         [0.8137]])
# torch.Size([2, 1])
