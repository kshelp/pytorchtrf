# %%
from transformers import pipeline


generator = pipeline(task="text-generation", model="gpt2")
outputs = generator(
    text_inputs="Machine learning is",
    max_length=20,
    num_return_sequences=3,
    pad_token_id=generator.tokenizer.eos_token_id
)
print(outputs)
# Out:
# [{'generated_text': 'Machine learning is a natural choice when developing AI systems. We can learn how to build human-controlled'}, {'generated_text': 'Machine learning is the most successful way to build a deep-learning model for a database on an O'}, {'generated_text': 'Machine learning is not limited only to Google Earth, but to several other companies as well.\n\n'}]
