# %%
from transformers import pipeline


generator = pipeline(task="text-generation", model="gpt2")
outputs = generator(
    text_inputs="Machine learning is",
    max_length=20,
    num_return_sequences=3,
    pad_token_id=generator.tokenizer.eos_token_id
)
print(outputs)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Machine learning is based upon the notion of a "memory-based" model. This is analogous to the way that we measure the performance of certain tasks.\n\nHowever, this is a very different kind of model from the "memory-based" one we would like to use.\n\nThe concept of a "memory-based" model is akin to what we would like to use if we were to ask the following question:\n\nWhat is the best way to learn a new language?\n\nFor example, what is the best way to learn a new language?\n\nThis is the kind of question that, even if you didn\'t understand it, you would probably want to ask.\n\nThe "memory" model is an example of how a memory model can be applied in a lot of different ways.\n\nFor example, let\'s say you want to know how many languages you can learn in a given semester.\n\nYou would ask this question:\n\nWhat is the best way to learn a new language?\n\nThe best memory model, as we have already seen, is a "memory-based" model.\n\nYou would then ask this question:\n\nWhat are the best ways to learn a new language?\n\nThe best model'}, {'generated_text': "Machine learning is a complex field and it's possible to create complex models. We can also create models for real-world uses as well, and we can use our knowledge of machine learning to help us create better solutions to problems.\n\nWhat tools do you use to do Machine learning?\n\nMachine learning is a complex field and it's possible to create complex models. We can also create models for real-world uses as well, and we can use our knowledge of machine learning to help us create better solutions to problems.\n\nWhat types of training are used to do Machine learning?\n\nMachine learning is a complex field and it's possible to create complex models. We can also create models for real-world uses as well, and we can use our knowledge of machine learning to help us create better solutions to problems.\n\nWhat tools do you use to do Machine learning?\n\nMachine learning is a complex field and it's possible to create complex models. We can also create models for real-world uses as well, and we can use our knowledge of machine learning to help us create better solutions to problems.\n\nWhat tools do you use to do Machine learning?\n\nMachine learning is a complex field and it's possible to create complex models. We can also"}, {'generated_text': "Machine learning is a very powerful but expensive method of learning. But the truth is that you can learn anything, and you do it just fine.\n\nHere are a few points to consider:\n\nKnowledge\n\nThere have been lots of theories about how knowledge comes from the brain, but most of them were based on the assumption that it is what you know. This is true for most of the sciences but you can learn anything you want by simply reading, listening, and using a good computer.\n\nIf you're reading this article, do not be fooled by the idea that learning is a very expensive process. The world is changing fast, but many of the concepts we thought that we could learn in a few years are now obsolete.\n\nTake a deep breath and look at what you have just read…\n\nLearning is not some magic thing with an infinite number of parts. It is an essential part of learning.\n\nYou can learn anything you want by simply reading, listening, and using a good computer. There are plenty of ways to learn to learn, but there is no way to learn without the ability to see and learn.\n\nThere are many articles from the internet that deal with the very basics of learning. There are many books to learn in"}]
